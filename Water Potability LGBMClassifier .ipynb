# %% [markdown]
# # About Dataset:

# %% [markdown]
# ### pH value:
# PH is an important parameter in evaluating the acid–base balance of water. It is also the indicator of acidic or alkaline condition of water status. WHO has recommended maximum permissible limit of pH from 6.5 to 8.5. The current investigation ranges were 6.52–6.83 which are in the range of WHO standards.

# %% [markdown]
# ### Hardness:
# Hardness is mainly caused by calcium and magnesium salts. These salts are dissolved from geologic deposits through which water travels. The length of time water is in contact with hardness producing material helps determine how much hardness there is in raw water. Hardness was originally defined as the capacity of water to precipitate soap caused by Calcium and Magnesium.

# %% [markdown]
# ### Solids (Total dissolved solids - TDS):
# Water has the ability to dissolve a wide range of inorganic and some organic minerals or salts such as potassium, calcium, sodium, bicarbonates, chlorides, magnesium, sulfates etc. These minerals produced un-wanted taste and diluted color in appearance of water. This is the important parameter for the use of water. The water with high TDS value indicates that water is highly mineralized. Desirable limit for TDS is 500 mg/l and maximum limit is 1000 mg/l which prescribed for drinking purpose.

# %% [markdown]
# ### Chloramines:
# Chlorine and chloramine are the major disinfectants used in public water systems. Chloramines are most commonly formed when ammonia is added to chlorine to treat drinking water. Chlorine levels up to 4 milligrams per liter (mg/L or 4 parts per million (ppm)) are considered safe in drinking water.

# %% [markdown]
# ### Sulfate:
# Sulfates are naturally occurring substances that are found in minerals, soil, and rocks. They are present in ambient air, groundwater, plants, and food. The principal commercial use of sulfate is in the chemical industry. Sulfate concentration in seawater is about 2,700 milligrams per liter (mg/L). It ranges from 3 to 30 mg/L in most freshwater supplies, although much higher concentrations (1000 mg/L) are found in some geographic locations.

# %% [markdown]
# ### Conductivity:
# Pure water is not a good conductor of electric current rather’s a good insulator. Increase in ions concentration enhances the electrical conductivity of water. Generally, the amount of dissolved solids in water determines the electrical conductivity. Electrical conductivity (EC) actually measures the ionic process of a solution that enables it to transmit current. According to WHO standards, EC value should not exceeded 400 μS/cm.

# %% [markdown]
# ### Organic_carbon:
# Total Organic Carbon (TOC) in source waters comes from decaying natural organic matter (NOM) as well as synthetic sources. TOC is a measure of the total amount of carbon in organic compounds in pure water. According to US EPA < 2 mg/L as TOC in treated / drinking water, and < 4 mg/Lit in source water which is use for treatment.

# %% [markdown]
# ### Trihalomethanes:
# THMs are chemicals which may be found in water treated with chlorine. The concentration of THMs in drinking water varies according to the level of organic material in the water, the amount of chlorine required to treat the water, and the temperature of the water that is being treated. THM levels up to 80 ppm is considered safe in drinking water.

# %% [markdown]
# ### Turbidity:
# The turbidity of water depends on the quantity of solid matter present in the suspended state. It is a measure of light emitting properties of water and the test is used to indicate the quality of w+aste discharge with respect to colloidal matter. The mean turbidity value obtained for Wondo Genet Campus (0.98 NTU) is lower than the WHO recommended value of 5.00 NTU.

# %% [markdown]
# ### Potability:
# Indicates if water is safe for human consumption where 1 means Potable and 0 means Not potable.

# %%
# Importing necessary libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
data = pd.read_csv('C:/Users/malho/Downloads/water_potability.csv')
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
data.shape
# Out:
# (3276, 10)

# %%
# descriptive analysis of numerical features
data.describe() 

#Potability should be categorical
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
data.isnull().sum().sum()
# Out:
# 1434

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.Potability.value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Dealing with null values
#
# When we have such a large number of missing values present in our data, we have 2 options.
# 1) Deletion : Deletion of rows (if you have large volume of data)
#
#           Deletion of columns (if > 50% of data is null)
# 2) Imputation: for numeric column-- use mean/median/mode
#
#           for categorical columns-- use mode or ration
#
#           Knn imputer
#
#           Simple Linear regression

# %%
# Column wise null values
total_null = data.isnull().sum().sort_values(ascending=False)  
percent_null = ((data.isnull().sum() / data.shape[0])*100 ).sort_values(ascending=False)
missing_data = pd.concat([total_null, percent_null], axis=1, keys=['Total_null', 'Percent_null'])
missing_data.head(10)
# Out:
#                  Total_null  Percent_null
# Sulfate                 781     23.840049
# ph                      491     14.987790
# Trihalomethanes         162      4.945055
# Potability                0      0.000000
# Turbidity                 0      0.000000
# Organic_carbon            0      0.000000
# Conductivity              0      0.000000
# Chloramines               0      0.000000
# Solids                    0      0.000000
# Hardness                  0      0.000000

# %% [markdown]
# #### Deletion is not a suitable option in this case.. lets explore more about imputation.

# %%
data.corr()

#Sulfate,ph,Trihalomethanes do not have strong correlation with any other parameter so cant use SLR for imputation.
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096 -0.089288    -0.034350  0.018203
# Hardness         0.082096  1.000000 -0.046899    -0.030054 -0.106923
# Solids          -0.089288 -0.046899  1.000000    -0.070148 -0.171804
# Chloramines     -0.034350 -0.030054 -0.070148     1.000000  0.027244
# Sulfate          0.018203 -0.106923 -0.171804     0.027244  1.000000
# Conductivity     0.018614 -0.023915  0.013831    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610  0.010242    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.009143     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449  0.019546     0.002363 -0.011187
# Potability      -0.003556 -0.013837  0.033743     0.023779 -0.023577
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.018614        0.043503         0.003354  -0.039057
# ...

# %%
data['Sulfate'].skew()
# Out:
# -0.03594662160706183

# %%
data['ph'].skew()
# Out:
# 0.025630447632210302

# %%
data['Trihalomethanes'].skew()
# Out:
# -0.08303067407901549

# %%
# these 3 columns are slightly skewed, lets replace null with median

# %%
data['Sulfate'] =data['Sulfate'].fillna(data['Sulfate'].median())

# %%
data['ph'] =data['ph'].fillna(data['ph'].median())

# %%
data['Trihalomethanes'] =data['Trihalomethanes'].fillna(data['Trihalomethanes'].median())

# %% [markdown]
# ## Visualisation

# %%
data.hist(figsize=(14,14))
plt.show()

# %%
# for continuous features -- Boxplot
fig, axes=plt.subplots(9,1,figsize=(14,34))

sns.boxplot(data.ph,  ax=axes[0])
sns.boxplot(data.Hardness,  ax=axes[1])
sns.boxplot(data.Solids,  ax=axes[2])
sns.boxplot(data.Chloramines,  ax=axes[3])
sns.boxplot(data.Sulfate,  ax=axes[4])
sns.boxplot(data.Conductivity,  ax=axes[5])
sns.boxplot(data.Organic_carbon,  ax=axes[6])
sns.boxplot(data.Trihalomethanes,  ax=axes[7])
sns.boxplot(data.Turbidity,  ax=axes[8])

#Lot of outliers, but we will not remove them since it will result into loss of data
# Out:
# <AxesSubplot:xlabel='Turbidity'>

# %%
sns.pairplot(data,hue='Potability')

# %% [markdown]
# ## Data Preprocessing

# %%
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.036752  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.073546
# 2     8.099124  224.236259  19909.541732     9.275884  333.073546
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.073546
# 3273  9.419510  175.762646  33155.578218     7.350233  333.073546
# 3274  5.126763  230.603758  11983.869376     6.303357  333.073546
# 3275  7.874671  195.102299  17404.177061     7.509306  333.073546
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
# segregation of dataset into input and output variables
X = data.iloc[:,0:9]
Y = data.iloc[:,9 ]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
y_train.value_counts()
# Out:
# 0    1318
# 1     876
# Name: Potability, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    680
# 1    402
# Name: Potability, dtype: int64

# %% [markdown]
# ### Balance data

# %%
from imblearn.over_sampling import SMOTE
smt = SMOTE()
X_train_sm , y_train_sm = smt.fit_resample(X_train , y_train)

# %%
X_train_sm.shape , y_train_sm.shape
# Out:
# ((2636, 9), (2636,))

# %%
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler()

# %%
X_train_ros ,y_train_ros = ros.fit_resample(X_train,y_train)

# %%
X_train_ros.shape, y_train_ros.shape
# Out:
# ((2636, 9), (2636,))

# %%
# Using UnderSampler
from collections import Counter
from imblearn.under_sampling import NearMiss
ns=NearMiss()
X_train_us,y_train_us = ns.fit_resample(X_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_us)))
# Out:
# The number of classes before fit Counter({0: 1318, 1: 876})
# The number of classes after fit Counter({0: 876, 1: 876})

# %%
from imblearn.combine import SMOTETomek
from collections import Counter

counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using SMOTE + Tomek
smtom = SMOTETomek(random_state=139)
X_train_smtom, y_train_smtom = smtom.fit_resample(X_train, y_train)

counter = Counter(y_train_smtom)
print('After',counter)
# Out:
# Before Counter({0: 1318, 1: 876})
# After Counter({1: 1120, 0: 1120})

# %% [markdown]
# ### LogisticRegression

# %%
from sklearn.metrics import accuracy_score 
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()
classifier.fit(X_train, y_train)  
y_pred = classifier.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6284658040665434

# %%
classifier1 = LogisticRegression()
classifier1.fit(X_train_sm, y_train_sm) 
y_pred = classifier1.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.5369685767097967

# %%
classifier2 = LogisticRegression()
classifier2.fit(X_train_ros, y_train_ros) 
y_pred = classifier2.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.5203327171903882

# %%
classifier3 = LogisticRegression()
classifier3.fit(X_train_us, y_train_us) 
y_pred = classifier3.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.5184842883548983

# %%
classifier4 = LogisticRegression()
classifier4.fit(X_train_smtom, y_train_smtom) 
y_pred = classifier4.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.5249537892791127

# %%
# Confusion Matrix for the model accuracy
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,y_pred)
print (confusion_matrix)

sns.heatmap(confusion_matrix, annot=True, fmt='d' )
plt.title("Confusion Matrix")
plt.xlabel("Predicted label")
plt.ylabel("Actual label")
plt.show()
# Out:
# [[381 299]
#  [215 187]]

# %% [markdown]
# ### Decison Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT_model=DecisionTreeClassifier(criterion='gini',max_depth=6,min_samples_split=6)
DT_model.fit(X_train,y_train)
DT_model_predict=DT_model.predict(X_test) 
accuracy_score(y_test,DT_model_predict)
# Out:
# 0.634011090573013

# %%
DT_model1=DecisionTreeClassifier(criterion='gini',max_depth=6,min_samples_split=6)
DT_model1.fit(X_train_sm,y_train_sm)
DT_model_predict=DT_model1.predict(X_test) 
accuracy_score(y_test,DT_model_predict)
# Out:
# 0.609981515711645

# %%
DT_model2=DecisionTreeClassifier(criterion='gini',max_depth=6,min_samples_split=6)
DT_model2.fit(X_train_ros,y_train_ros) 
DT_model_predict=DT_model2.predict(X_test) 
accuracy_score(y_test,DT_model_predict)
# Out:
# 0.6423290203327172

# %%
DT_model3=DecisionTreeClassifier(criterion='gini',max_depth=6,min_samples_split=6)
DT_model3.fit(X_train_us,y_train_us) 
DT_model_predict=DT_model3.predict(X_test) 
accuracy_score(y_test,DT_model_predict)
# Out:
# 0.5628465804066544

# %%
DT_model4=DecisionTreeClassifier(criterion='gini',max_depth=6,min_samples_split=6)
DT_model4.fit(X_train_smtom,y_train_smtom)  
DT_model_predict=DT_model4.predict(X_test) 
accuracy_score(y_test,DT_model_predict)
# Out:
# 0.6164510166358595

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

# %%
## Calculate optimum value of K 
Accuracy=[]
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i=knn.predict(X_test)
    Accuracy.append(accuracy_score(pred_i,y_test))

# %%
plt.figure(figsize=(10,5))
plt.plot(range(1,40),Accuracy,markersize = 40)
plt.title("Accuracy  VS K ")
plt.ylabel('Accuracy')
plt.xlabel('K')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=40)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=40)

# %%
knn_Test_pred=knn.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,knn_Test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.96      0.76       680
#            1       0.48      0.06      0.11       402
#
#     accuracy                           0.63      1082
#    macro avg       0.56      0.51      0.44      1082
# weighted avg       0.58      0.63      0.52      1082

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
nb =  GaussianNB()        
nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6395563770794824

# %%
nb1=  GaussianNB()        
nb1.fit(X_train_sm, y_train_sm)
y_pred = nb1.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.566543438077634

# %%
nb2 =  GaussianNB()        
nb2.fit(X_train_us, y_train_us) 
y_pred = nb2.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5757855822550831

# %%
nb3 =  GaussianNB()        
nb3.fit(X_train_smtom, y_train_smtom)
y_pred = nb3.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5720887245841035

# %%
nb4 =  GaussianNB()        
nb4.fit(X_train_ros, y_train_ros)
y_pred = nb4.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6062846580406654

# %% [markdown]
# ### SVM

# %%
sm =  SVC()        
sm.fit(X_train, y_train)
y_pred = sm.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6284658040665434

# %%
sm1 =  SVC()        
sm1.fit(X_train_sm, y_train_sm) 
y_pred = sm1.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5942698706099815

# %%
sm2 =  SVC()        
sm2.fit(X_train_ros, y_train_ros) 
y_pred = sm2.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5951940850277264

# %%
sm3 =  SVC()        
sm3.fit(X_train_us, y_train_us) 
y_pred = sm3.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5767097966728281

# %%
sm4 =  SVC()        
sm4.fit(X_train_smtom, y_train_smtom) 
y_pred = sm4.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5914972273567468

# %% [markdown]
# ### Random Forest

# %%
rf =  RandomForestClassifier()        
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.678373382624769

# %%
rf1 =  RandomForestClassifier()        
rf1.fit(X_train_sm, y_train_sm) 
y_pred = rf1.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.6635859519408502

# %%
rf2 =  RandomForestClassifier()        
rf2.fit(X_train_ros, y_train_ros) 
y_pred = rf2.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.6635859519408502

# %%
rf3 =  RandomForestClassifier()        
rf3.fit(X_train_us, y_train_us) 
y_pred = rf3.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.6192236598890942

# %%
rf4 =  RandomForestClassifier()        
rf4.fit(X_train_smtom, y_train_smtom) 
y_pred = rf4.predict(X_test) 
accuracy_score(y_test, y_pred)
# Out:
# 0.6469500924214417

# %% [markdown]
# ### Gradient Boosting

# %%
Gb =  GradientBoostingClassifier()        
Gb.fit(X_train, y_train) 
y_pred = Gb.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6635859519408502

# %%
Gb1 =  GradientBoostingClassifier()        
Gb1.fit(X_train_sm, y_train_sm) 
y_pred = Gb1.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6321626617375231

# %%
Gb2 =  GradientBoostingClassifier()        
Gb2.fit(X_train_ros, y_train_ros) 
y_pred = Gb2.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6414048059149723

# %%
Gb3 =  GradientBoostingClassifier()        
Gb3.fit(X_train_us, y_train_us)  
y_pred = Gb3.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5924214417744916

# %%
Gb4 =  GradientBoostingClassifier()        
Gb4.fit(X_train_smtom, y_train_smtom) 
y_pred = Gb4.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6182994454713494

# %% [markdown]
# ### XgBoost

# %%
import xgboost as xgb
xgb_clf=xgb.XGBClassifier() 
xgb_clf.fit(X_train, y_train)
y_pred = xgb_clf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6497227356746765

# %%
xgb_clf1=xgb.XGBClassifier() 
xgb_clf1.fit(X_train_sm, y_train_sm)
y_pred = xgb_clf1.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6146025878003697

# %%
xgb_clf2=xgb.XGBClassifier() 
xgb_clf2.fit(X_train_ros, y_train_ros)
y_pred = xgb_clf2.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6386321626617375

# %%
xgb_clf3=xgb.XGBClassifier() 
xgb_clf3.fit(X_train_us, y_train_us)
y_pred = xgb_clf3.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.609981515711645

# %%
xgb_clf4=xgb.XGBClassifier() 
xgb_clf4.fit(X_train_smtom, y_train_smtom) 
y_pred = xgb_clf4.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6266173752310537

# %% [markdown]
# # LGBM

# %%
import lightgbm as lgb
lgbm_clf=lgb.LGBMClassifier() 
lgbm_clf.fit(X_train, y_train)
y_pred = lgbm_clf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6737523105360443

# %%
lgbm_clf1=lgb.LGBMClassifier() 
lgbm_clf1.fit(X_train_sm, y_train_sm)
y_pred = lgbm_clf1.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6414048059149723

# %%
lgbm_clf2=lgb.LGBMClassifier() 
lgbm_clf2.fit(X_train_ros, y_train_ros)
y_pred = lgbm_clf2.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6469500924214417

# %%
lgbm_clf3=lgb.LGBMClassifier() 
lgbm_clf3.fit(X_train_us, y_train_us)
y_pred = lgbm_clf3.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6136783733826248

# %%
lgbm_clf4=lgb.LGBMClassifier() 
lgbm_clf4.fit(X_train_smtom, y_train_smtom) 
y_pred = lgbm_clf4.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6377079482439926

# %% [markdown]
# # Save Model

# %%
import pickle

# %%
pickle.dump(lgbm_clf, open('lgbm_clf.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('lgbm_clf.pkl', 'rb'))
lgbm_pred = pickled_model.predict(X_test)

# %%
acc=accuracy_score(y_test,lgbm_pred)
print(acc)
# Out:
# 0.6737523105360443

# %%
input_data = (8.197353369384867,203.1050914346406,27701.794054691156,6.472914285587643,328.88683761881884,444.612723622325,14.25087508151961,62.90620518305302,3.3618333238544555
)

#changing input data as numpy array
input_as_np = np.array(input_data,dtype=np.float64)

#reshaping the data
input_reshaped = input_as_np.reshape(1,-1)


prediction_lgbm = pickled_model.predict(input_reshaped)
print(prediction_lgbm)

if(prediction_lgbm[0] == 0):
    print('The water is not potable')
else:
    print('The water is potable')
# Out:
# [0]
# The water is not potable

# %%
print(input_data)
# Out:
# (8.197353369384867, 203.1050914346406, 27701.794054691156, 6.472914285587643, 328.88683761881884, 444.612723622325, 14.25087508151961, 62.90620518305302, 3.3618333238544555)
